# %%
import pandas as pd
import numpy as np
import re

import mlflow

# %%
df = pd.read_csv('../data/preprocessing_train.csv')

# %%
def clean_feature_names(df):
    df.columns = [re.sub(r'[^a-zA-Z0-9_]', '_', col) for col in df.columns]
    return df

# %%
best_features = pd.read_csv('../data/df_best_features.csv')
df = clean_feature_names(best_features)

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
mlflow.set_tracking_uri('http://127.0.0.1:5000/')

# Créer une nouvelle expérience
experiment_id = mlflow.create_experiment('Pycaret')

with mlflow.start_run(experiment_id=experiment_id, run_name="Compare models"):
    clf1 = setup(df, target='TARGET', log_experiment=True, experiment_name='Pycaret')
    best_model = compare_models()
# Out:
# <style type="text/css">
# #T_07b27_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_07b27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07b27_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_07b27_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07b27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07b27_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_07b27_row0_col1" class="data row0 col1" >4565</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07b27_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_07b27_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07b27_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_07b27_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07b27_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_07b27_row3_col1" class="data row3 col1" >(307507, 161)</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07b27_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_07b27_row4_col1" class="data row4 col1" >(307507, 161)</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07b27_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_07b27_row5_col1" class="data row5 col1" >(215254, 161)</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_07b27_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_07b27_row6_col1" class="data row6 col1" >(92253, 161)</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_07b27_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_07b27_row7_col1" class="data row7 col1" >160</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_07b27_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_07b27_row8_col1" class="data row8 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_07b27_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_07b27_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_07b27_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_07b27_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_07b27_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_07b27_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_07b27_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_07b27_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_07b27_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_07b27_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_07b27_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_07b27_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_07b27_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_07b27_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_07b27_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_07b27_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_07b27_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_07b27_row17_col1" class="data row17 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_07b27_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_07b27_row18_col1" class="data row18 col1" >Pycaret</td>
#     </tr>
#     <tr>
#       <th id="T_07b27_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_07b27_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_07b27_row19_col1" class="data row19 col1" >5373</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1f3c8 th {
#   text-align: left;
# }
# #T_1f3c8_row0_col0, #T_1f3c8_row0_col3, #T_1f3c8_row0_col4, #T_1f3c8_row0_col5, #T_1f3c8_row0_col6, #T_1f3c8_row0_col7, #T_1f3c8_row1_col0, #T_1f3c8_row1_col1, #T_1f3c8_row1_col2, #T_1f3c8_row1_col3, #T_1f3c8_row1_col4, #T_1f3c8_row1_col5, #T_1f3c8_row1_col6, #T_1f3c8_row1_col7, #T_1f3c8_row2_col0, #T_1f3c8_row2_col1, #T_1f3c8_row2_col2, #T_1f3c8_row2_col3, #T_1f3c8_row2_col5, #T_1f3c8_row2_col6, #T_1f3c8_row2_col7, #T_1f3c8_row3_col0, #T_1f3c8_row3_col1, #T_1f3c8_row3_col2, #T_1f3c8_row3_col3, #T_1f3c8_row3_col4, #T_1f3c8_row3_col5, #T_1f3c8_row3_col6, #T_1f3c8_row3_col7, #T_1f3c8_row4_col0, #T_1f3c8_row4_col1, #T_1f3c8_row4_col2, #T_1f3c8_row4_col3, #T_1f3c8_row4_col4, #T_1f3c8_row4_col5, #T_1f3c8_row4_col6, #T_1f3c8_row4_col7, #T_1f3c8_row5_col0, #T_1f3c8_row5_col1, #T_1f3c8_row5_col2, #T_1f3c8_row5_col3, #T_1f3c8_row5_col4, #T_1f3c8_row5_col5, #T_1f3c8_row5_col6, #T_1f3c8_row5_col7, #T_1f3c8_row6_col0, #T_1f3c8_row6_col1, #T_1f3c8_row6_col2, #T_1f3c8_row6_col3, #T_1f3c8_row6_col4, #T_1f3c8_row6_col5, #T_1f3c8_row6_col6, #T_1f3c8_row6_col7, #T_1f3c8_row7_col0, #T_1f3c8_row7_col1, #T_1f3c8_row7_col2, #T_1f3c8_row7_col3, #T_1f3c8_row7_col4, #T_1f3c8_row7_col5, #T_1f3c8_row7_col6, #T_1f3c8_row7_col7, #T_1f3c8_row8_col0, #T_1f3c8_row8_col1, #T_1f3c8_row8_col2, #T_1f3c8_row8_col3, #T_1f3c8_row8_col4, #T_1f3c8_row8_col5, #T_1f3c8_row9_col0, #T_1f3c8_row9_col1, #T_1f3c8_row9_col2, #T_1f3c8_row9_col3, #T_1f3c8_row9_col4, #T_1f3c8_row9_col5, #T_1f3c8_row9_col6, #T_1f3c8_row9_col7, #T_1f3c8_row10_col0, #T_1f3c8_row10_col1, #T_1f3c8_row10_col2, #T_1f3c8_row10_col3, #T_1f3c8_row10_col4, #T_1f3c8_row10_col5, #T_1f3c8_row10_col6, #T_1f3c8_row10_col7, #T_1f3c8_row11_col0, #T_1f3c8_row11_col1, #T_1f3c8_row11_col2, #T_1f3c8_row11_col3, #T_1f3c8_row11_col4, #T_1f3c8_row11_col5, #T_1f3c8_row11_col6, #T_1f3c8_row11_col7, #T_1f3c8_row12_col0, #T_1f3c8_row12_col1, #T_1f3c8_row12_col2, #T_1f3c8_row12_col3, #T_1f3c8_row12_col4, #T_1f3c8_row12_col5, #T_1f3c8_row12_col6, #T_1f3c8_row12_col7, #T_1f3c8_row13_col0, #T_1f3c8_row13_col1, #T_1f3c8_row13_col2, #T_1f3c8_row13_col3, #T_1f3c8_row13_col4, #T_1f3c8_row13_col6, #T_1f3c8_row13_col7, #T_1f3c8_row14_col0, #T_1f3c8_row14_col1, #T_1f3c8_row14_col2, #T_1f3c8_row14_col4, #T_1f3c8_row14_col5, #T_1f3c8_row14_col6, #T_1f3c8_row14_col7 {
#   text-align: left;
# }
# #T_1f3c8_row0_col1, #T_1f3c8_row0_col2, #T_1f3c8_row2_col4, #T_1f3c8_row8_col6, #T_1f3c8_row8_col7, #T_1f3c8_row13_col5, #T_1f3c8_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1f3c8_row0_col8, #T_1f3c8_row1_col8, #T_1f3c8_row2_col8, #T_1f3c8_row3_col8, #T_1f3c8_row4_col8, #T_1f3c8_row6_col8, #T_1f3c8_row7_col8, #T_1f3c8_row8_col8, #T_1f3c8_row9_col8, #T_1f3c8_row10_col8, #T_1f3c8_row11_col8, #T_1f3c8_row12_col8, #T_1f3c8_row13_col8, #T_1f3c8_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1f3c8_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1f3c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f3c8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1f3c8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1f3c8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1f3c8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1f3c8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1f3c8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1f3c8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1f3c8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1f3c8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f3c8_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_1f3c8_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1f3c8_row0_col1" class="data row0 col1" >0.9197</td>
#       <td id="T_1f3c8_row0_col2" class="data row0 col2" >0.7793</td>
#       <td id="T_1f3c8_row0_col3" class="data row0 col3" >0.0369</td>
#       <td id="T_1f3c8_row0_col4" class="data row0 col4" >0.5408</td>
#       <td id="T_1f3c8_row0_col5" class="data row0 col5" >0.0691</td>
#       <td id="T_1f3c8_row0_col6" class="data row0 col6" >0.0594</td>
#       <td id="T_1f3c8_row0_col7" class="data row0 col7" >0.1256</td>
#       <td id="T_1f3c8_row0_col8" class="data row0 col8" >3.4310</td>
#     </tr>
#     <tr>
#       <th id="T_1f3c8_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_1f3c8_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1f3c8_row1_col1" class="data row1 col1" >0.9196</td>
#       <td id="T_1f3c8_row1_col2" class="data row1 col2" >0.7697</td>
#       <td id="T_1f3c8_row1_col3" class="data row1 col3" >0.0196</td>
#       <td id="T_1f3c8_row1_col4" class="data row1 col4" >0.5542</td>
#       <td id="T_1f3c8_row1_col5" class="data row1 col5" >0.0379</td>
#       <td id="T_1f3c8_row1_col6" class="data row1 col6" >0.0325</td>
#       <td id="T_1f3c8_row1_col7" class="data row1 col7" >0.0929</td>
#       <td id="T_1f3c8_row1_col8" class="data row1 col8" >61.6480</td>
#     </tr>
#     <tr>
#       <th id="T_1f3c8_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_1f3c8_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_1f3c8_row2_col1" class="data row2 col1" >0.9194</td>
#       <td id="T_1f3c8_row2_col2" class="data row2 col2" >0.7267</td>
#       <td id="T_1f3c8_row2_col3" class="data row2 col3" >0.0021</td>
#       <td id="T_1f3c8_row2_col4" class="data row2 col4" >0.7908</td>
#       <td id="T_1f3c8_row2_col5" class="data row2 col5" >0.0041</td>
#       <td id="T_1f3c8_row2_col6" class="data row2 col6" >0.0037</td>
#       <td id="T_1f3c8_row2_col7" class="data row2 col7" >0.0372</td>
#       <td id="T_1f3c8_row2_col8" class="data row2 col8" >25.2170</td>
#     </tr>
#     <tr>
#       <th id="T_1f3c8_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_1f3c8_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_1f3c8_row3_col1" class="data row3 col1" >0.9194</td>
#       <td id="T_1f3c8_row3_col2" class="data row3 col2" >0.7293</td>
#       <td id="T_1f3c8_row3_col3" class="data row3 col3" >0.0015</td>
#       <td id="T_1f3c8_row3_col4" class="data row3 col4" >0.7264</td>
#       <td id="T_1f3c8_row3_col5" class="data row3 col5" >0.0030</td>
#       <td id="T_1f3c8_row3_col6" class="data row3 col6" >0.0027</td>
#       <td id="T_1f3c8_row3_col7" class="data row3 col7" >0.0298</td>
#       <td id="T_1f3c8_row3_col8" class="data row3 col8" >17.0880</td>
#     </tr>
#     <tr>
#       <th id="T_1f3c8_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_1f3c8_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_1f3c8_row4_col1" class="data row4 col1" >0.9193</td>
#       <td id="T_1f3c8_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_1f3c8_row4_col3" class="data row4 col3" >0.0003</td>
#       <td id="T_1f3c8_row4_col4" class="data row4 col4" >0.2650</td>
#       <td id="T_1f3c8_row4_col5" class="data row4 col5" >0.0006</td>
#       <td id="T_1f3c8_row4_col6" class="data row4 col6" >0.0004</td>
#       <td id="T_1f3c8_row4_col7" class="data row4 col7" >0.0066</td>
#       <td id="T_1f3c8_row4_col8" class="data row4 col8" >0.5810</td>
#     </tr>
#     <tr>
#       <th id="T_1f3c8_level0_row5" class="row_heading level0 row5" >dummy</th>
#       <td id="T_1f3c8_row5_col0" class="data row5 col0" >Dummy Classifier</td>
#       <td id="T_1f3c8_row5_col1" class="data row5 col1" >0.9193</td>
#       <td id="T_1f3c8_row5_col2" class="data row5 col2" >0.5000</td>
#       <td id="T_1f3c8_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_1f3c8_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_1f3c8_r
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
# OOP API
s.evaluate_model(best)

# %%
s.plot_model(best, plot = 'auc')

# %%
# OOP API
s.plot_model(best, plot = 'confusion_matrix')

# %% [markdown]
# ## Save model

# %%
s.save_model(best, '../models/my_best_pipeline')
